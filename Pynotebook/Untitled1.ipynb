// %%
#include "MultGausTest.h"
gROOT -> ProcessLine(".L mymacros.c");
// Out:
// input_line_61:3:4: error: expected unqualified-id
// rt.gROOT.ProcessLine(".L mymacros.C")
//    ^
// /Users/runner/miniforge3/conda-bld/bld/rattler-build_root_base_1771471243/work/build-dir/include/TROOT.h:411:15: note: expanded from macro 'gROOT'
// #define gROOT (ROOT::GetROOT())
//               ^

// %%
TH1D
// Out:
// (TH1D &) Name:  Title:  NbinsX: 1

// %%
Decay_exp(h)
// Out:
// input_line_60:2:13: error: use of undeclared identifier 'h'
//  (Decay_exp(h))
//             ^
