# %%
import ROOT as rt
rt.gROOT.LoadMacro("mymacros.C+")
file = rt.TFile("e21062_44S.root")
dtimeN = file.Get("dtimeN")
Draw(dtimeN)
# Out:
# ---------------------------------------------------------------------------
# SegmentationViolation                     Traceback (most recent call last)
# Cell In[18], line 2
#       1 import ROOT as rt
# ----> 2 rt.gROOT.LoadMacro("mymacros.c+")
#       3 file = rt.TFile("e21062_44S.root")
#       4 dtimeN = file.Get("dtimeN")
#
# SegmentationViolation: segfault in C++; program state was reset
# [/opt/anaconda3/envs/Sulfur/lib/libCPyCppyy.6.38.00.so] (anonymous namespace)::TExceptionHandlerImp::HandleException(int) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCore.6.38.00.so] TUnixSystem::DispatchSignals(ESignals) (no debug info)
# [/usr/lib/system/libsystem_platform.dylib] _sigtramp (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCling.6.38.00.so] cling::TransactionUnloader::RevertTransaction(cling::Transaction*) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCling.6.38.00.so] cling::Interpreter::unload(cling::Transaction&) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCling.6.38.00.so] cling::Interpreter::unload(unsigned int) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCling.6.38.00.so] cling::MetaSema::actOnUCommand(llvm::StringRef) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCling.6.38.00.so] cling::MetaParser::isUCommand(cling::MetaSema::ActionResult&) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCling.6.38.00.so] cling::MetaParser::isCommand(cling::MetaSema::ActionResult&, cling::Value*) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCling.6.38.00.so] cling::MetaProcessor::process(llvm::StringRef, cling::Interpreter::CompilationResult&, cling::Value*, bool) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCling.6.38.00.so] HandleInterpreterException(cling::MetaProcessor*, char const*, cling::Interpreter::CompilationResult&, cling::Value*) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCling.6.38.00.so] TCling::UnloadFile(char const*) const (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCore.6.38.00.so] TSystem::CompileMacro(char const*, char const*, char const*, char const*, unsigned int) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCling.6.38.00.so] TCling::ProcessLine(char const*, TInterpreter::EErrorCode*) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCore.6.38.00.so] TROOT::LoadMacro(char const*, int*, bool) (no debug info)
# [<unknown binary>] (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCPyCppyy.6.38.00.so] WrapperCall(long, unsigned long, void*, void*, void*) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCPyCppyy.6.38.00.so] Cppyy::CallI(long, void*, unsigned long, void*) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCPyCppyy.6.38.00.so] CPyCppyy::(anonymous namespace)::IntExecutor::Execute(long, void*, CPyCppyy::CallContext*) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCPyCppyy.6.38.00.so] CPyCppyy::CPPMethod::ExecuteFast(void*, long, CPyCppyy::CallContext*) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCPyCppyy.6.38.00.so] CPyCppyy::CPPMethod::ExecuteProtected(void*, long, CPyCppyy::CallContext*) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCPyCppyy.6.38.00.so] CPyCppyy::CPPMethod::Call(CPyCppyy::CPPInstance*&, _object* const*, unsigned long, _object*, CPyCppyy::CallContext*) (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/libCPyCppyy.6.38.00.so] CPyCppyy::(anonymous namespace)::mp_vectorcall(CPyCppyy::CPPOverload*, _object* const*, unsigned long, _object*) (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] PyObject_Vectorcall (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] PyEval_EvalCode (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] builtin_exec (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] gen_send_ex2 (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] gen_send_ex2 (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] gen_send_ex2 (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] gen_send_ex (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] _PyEval_Vector (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] method_vectorcall (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] _PyVectorcall_Call (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] gen_send_ex2 (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] gen_send_ex2 (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] gen_send_ex2 (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] gen_send_ex2 (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] gen_send_ex2 (no debug info)
# [/opt/anaconda3/envs/Sulfur/lib/python3.11/lib-dynload/_asyncio.cpython-311-darwin.so] task_step (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] _PyObject_MakeTpCall (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] context_run (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] cfunction_vectorcall_FASTCALL_KEYWORDS (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] PyEval_EvalCode (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] builtin_exec (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] cfunction_vectorcall_FASTCALL_KEYWORDS (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] PyObject_Vectorcall (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] _PyEval_Vector (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] pymain_run_module (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] Py_RunMain (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] pymain_main (no debug info)
# [/opt/anaconda3/envs/Sulfur/bin/python3.11] main (no debug info)
# [/usr/lib/dyld] start (no debug info)
# Info in <ACLiC>: script has already been loaded in interpreted mode
# Info in <ACLiC>: unloading /Users/macwheeler/Sulfur_Research/./mymacros.c and compiling it
#  *** Break *** bus error

# %%
#44SGated
def decay_parent(x, par):
    """
    a = amplitude
    b = decay constant (lambda)
    bkgrd = constant background
    """
    a = par[0]
    b = par[1]
    bkgrd = par[2]
    t = x[0]

    return a * rt.TMath.Exp(-b * t) + bkgrd

def Decayp(hist):
    
    MaxX = hist.GetXaxis().GetXmax();
    #MinX = hist.GetXaxis().GetXmin();
    # Axis range
    MinX = 1
    #MaxX = 
    
    print("Min X: ", MinX)
    print("Max X: ", MaxX)
    
    # Canvas
    fitgraph = rt.TCanvas("fits", "fits", 800, 600)
    fitgraph.Clear()

    # Parent half-life guess
    Parent_halflife = rt.TMath.Log(2) / 101.0

    # Define TF1
    decayp = rt.TF1("decayp", decay_parent, MinX, MaxX, 3)

    decayp.SetParName(0, "source #")
    decayp.SetParName(1, "Source lambda")
    decayp.SetParName(2, "shift")

    decayp.SetParameters(200, Parent_halflife, 200) # intial conditions

    decayp.SetParLimits(0, 0, 500) # source
    decayp.SetParLimits(1, 0, 1) # lambda
    decayp.SetParLimits(2, 0, 400) # bckgrnd

    # Print initial parameters
    for i in range(decayp.GetNpar()):
        print(f"Initial p{i} = {decayp.GetParameter(i)}")

    # Perform fit
    hist.Fit("decayp", "RS", "", MinX, MaxX)
    #hist.Print("V")
    
    # Print parameter limits
    for i in range(decayp.GetNpar()):
        par_min = ctypes.c_double()
        par_max = ctypes.c_double()
        decayp.GetParLimits(i, par_min, par_max)
        print(f"Parameter {i} ({decayp.GetParName(i)}) limits: [{par_min}, {par_max}]")

    # Half-life calculation
    lambda_fit = decayp.GetParameter(1)
    lambda_err = decayp.GetParError(1)

    decayhl = rt.TMath.Log(2) / lambda_fit
    decay_error = (rt.TMath.Log(2) / (lambda_fit**2)) * lambda_err

    print(f"Decay: {decayhl:.6f} ms ± {decay_error:.6f} ms\n")

    # Chi2 / NDF
    chi2 = decayp.GetChisquare()
    ndf = decayp.GetNDF()
    print(f"Chi^2/NDF: {chi2/ndf:.6f}\n")

    # Constant background function
    bckgrnd = rt.TF1("bckgrnd", "[0]", MinX, MaxX)
    bckgrnd.SetParameter(0, decayp.GetParameter(2))
    bckgrnd.SetLineColor(rt.kBlack)

    # Legend
    legend = rt.TLegend(0.7, 0.4, 0.9, 0.7)
    legend.AddEntry(hist, "Data", "E")
    legend.AddEntry(decayp, "Fit", "l")
    legend.AddEntry(bckgrnd, "backgrnd", "l")

    # Styling
    hist.SetTitle("Decay of 44S Gated on 2789 keV;Time (ms);Counts")
    hist.GetXaxis().CenterTitle(True)
    hist.GetYaxis().CenterTitle(True)
    hist.SetLineColor(rt.kBlue)

    # Draw
    hist.Draw("E")
    decayp.SetLineColor(rt.kRed)
    decayp.Draw("same")
    bckgrnd.Draw("same")
    fitgraph.Draw()
    hist.Print("V")
    # legend.Draw()  # Uncomment if desired

    fitgraph.SaveAs("GammaNTest.png")

# %%
gamma_canvas = rt.TCanvas("gamma_canvas", "gamma_2789")
gamma_2789 = dtimeN.ProjectionX("Decay_Curve_2789keV",2781,2790)
#Decayp(gamma_2789)
#gamma_canvas.Update()
#gamma_canvas.Draw()

bckgrnd_2789 = dtimeN.ProjectionX("Decay_Curve_2789keV_bckgnd",2811,2820)
gamma_2789.Add(bckgrnd_2789,-1)
gamma_2789.Draw()

# %%
Decayp(gamma_2789)
gamma_canvas.Update()
Draw(gamma_canvas)
# Out:
# Min X:  1
# Max X:  1000.0
# Initial p0 = 200.0
# Initial p1 = 0.0068628433718806465
# Initial p2 = 200.0
# Parameter 0 (source #) limits: [c_double(0.0), c_double(500.0)]
# Parameter 1 (Source lambda) limits: [c_double(0.0), c_double(1.0)]
# Parameter 2 (shift) limits: [c_double(0.0), c_double(400.0)]
# Decay: 144.562760 ms ± 33.784930 ms
#
# Chi^2/NDF: 1.244627
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 Decayp(gamma_2789)
#       2 gamma_canvas.Update()
# ----> 3 Draw(gamma_canvas)
#
# NameError: name 'Draw' is not defined
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      1172.44
# NDf                       =          942
# Edm                       =  4.74847e-07
# NCalls                    =          180
# source #                  =      2.46112   +/-   0.284754     	 (limited)
# Source lambda             =   0.00479478   +/-   0.00112056   	 (limited)
# shift                     =      2.15398   +/-   0.107938     	 (limited)
# TH1.Print Name  = Decay_Curve_2789keV, Entries= 3596, Total sum= 3596
# In file included from input_line_92:1:
# In file included from /opt/anaconda3/envs/Sulfur/include/CPyCppyy/API.h:26:
# In file included from /opt/anaconda3/envs/Sulfur/include/python3.11/Python.h:92:
# /opt/anaconda3/envs/Sulfur/include/python3.11/compile.h:8:9: warning: 'Py_single_input' macro redefined [-Wmacro-redefined]
# #define Py_single_input 256
#         ^
# :49:1: note: previous definition is here
#    }
# ^
# Info in <TCanvas::Print>: png file GammaNTest.png has been created
# <div id="root_plot_1772034500181" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1772034500181() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(41352,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1772034500181', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1772034500181();
# </script>
